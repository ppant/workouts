# %%
import csv as cv

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('MAF_Data_PP_CSV1.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')    

# I need to make a plot based on Max HR, avg HR, distance and pace
plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('MAF run analysis')
plt.legend()
plt.show()
